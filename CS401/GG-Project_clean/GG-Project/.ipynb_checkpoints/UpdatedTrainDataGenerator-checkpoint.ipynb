# %%
from Sparker.Logic.UpdatedProductPreferrer import *
def getUpdatedLabeledPairsOnJupyter(jour):
    print_('On Jupyter...')
    journeys = jour.filter(lambda x: keyIn('_c', x)).sortBy(lambda x: x['timestamp']).groupBy(lambda x: x['_c']).collect()
    events = []

    def lookActions(action, journey):
        if action['module'] == 'cart' or action['module'] == 'payment':
            journey = modulize(journey)
            id = action['id']
            if keyIn('search', journey):
                for log in journey['search']:
                    if keyIn('ids', log):
                        if id in log['ids']:
                            #events.append({'product': action['id'], 'action': action['module'], 'others': log['ids']})
                            events.append((action['id'], action['module'], log['ids']))

    for c, journey in journeys:
        journey = list(journey)
        for i in range(4, len(journey)):
            lookActions(journey[i], journey[i-4:i])
            
    positive = 1
    negative = -1
    posPairs = []
    negPairs = []
    counts = {}
    labeledPairs = {}

    def posKey(id, module, otherId): return str((id, module, otherId))

    #idsSet = unique(list(map(lambda x: x['products'], events)))
    for id, module, others in events:
        for otherId in others:
            k = posKey(id, module, otherId)
            l = posKey(otherId, module, id)
            if keyIn(k, counts):
                counts[k] += 1
            else:
                counts[k] = 1
            posPairs.append((id, module, otherId, k))
            negPairs.append((otherId, module, id, l))

    for ke in list(counts.keys()):
        id, module, otherId = eval(ke)
        if module == 'payment':
            rev = posKey(otherId, module, id)
            if keyIn(rev, counts):
                if counts[ke] > counts[rev]:
                    labeledPairs[keyPairIds(id, otherId)] = positive
                    labeledPairs[keyPairIds(otherId, id)] = negative
        elif module == 'cart' and not keyIn(posKey(id, 'payment', otherId), counts) and not keyIn(posKey(otherId, 'payment', id), counts):
            rev = posKey(otherId, module, id)
            if keyIn(rev, counts):
                if counts[ke] > counts[rev]:
                    labeledPairs[keyPairIds(id, otherId)] = positive
                    labeledPairs[keyPairIds(otherId, id)] = negative
             
    labeledPairs = sc_().parallelize([(key, v) for key, v in labeledPairs.items()])
    print_(labeledPairs.count(), 'labeled pairs have been generated by', nowStr())
    return labeledPairs

# %%
from Sparker.Logic import UpdatedProductPreferrer
original = UpdatedProductPreferrer.getUpdatedLabeledPairs
#UpdatedProductPreferrer.getUpdatedLabeledPairs = getUpdatedLabeledPairsOnJupyter

# %%
from MainSrc.PythonVersionHandler import *
from paths import *
from Sparker.SparkLogProcesser.SparkLogOperator import *
from Sparker.SparkLogProcesser.SparkLogReader import *
from Sparker.SparkLogProcesser.SparkLogAnalyzer import *
from Sparker.SparkLogProcesser.SparkLogFileHandler import *
from Sparker.PySparkImports import *
from Sparker.Logic.Trainer import *
from Sparker.Logic.UpdatedProductPreferrer import *

# %%
from Sparker.SparkLogProcesser.SparkLogFileHandler import setSparkContext
from pyspark import SparkContext
try:
    sc = SparkContext() 
    setSparkContext(sc)
except ValueError:
    pass

# %%
from runGG_Project import main as run
from Sparker.Logic import LogicTests
from Sparker.Logic.TrainDataGenerator import *
def gen(): runUpdatedTrainDataGenerationTest(i = 7, clicks = True, oneHot = True, org True)
#run(LogicTests.trainLocalDataTest, False)
run(gen, False)
# Out:
# ########################################################################################
# ########################################################################################
# ########################################################################################
# 2017-05-23 23:41:11.428566: Running on osldevptst02...
# hdfs://osldevptst01.host.gittigidiyor.net:8020/user/root/data/Day1_tv_unitesi_Data/all_day_tv_unitesi_journey_products 2166  products have been read successfully by 2017-05-23 23:41:12.696724
# LabeledPairs And Products for tv_unitesi have been read successfully by 2017-05-23 23:41:12.699343
# train instances is being generated by 2017-05-23 23:41:12.702249
# 50034 train instances have been generated by 2017-05-23 23:41:15.214659
# all_day_tv_unitesi_TrainData_Updated_OneHot2 has been saved successfully by 2017-05-23 23:41:18.602909
# hdfs://osldevptst01.host.gittigidiyor.net:8020/user/root/data/Day1_iphone_6_Data/all_day_iphone_6_journey_products 2757  products have been read successfully by 2017-05-23 23:41:19.937506
# LabeledPairs And Products for iphone_6 have been read successfully by 2017-05-23 23:41:19.941116
# train instances is being generated by 2017-05-23 23:41:19.943505
# 7334 train instances have been generated by 2017-05-23 23:41:21.629741
# all_day_iphone_6_TrainData_Updated_OneHot2 has been saved successfully by 2017-05-23 23:41:22.949147
# hdfs://osldevptst01.host.gittigidiyor.net:8020/user/root/data/Day1_nike_air_max_Data/all_day_nike_air_max_journey_products 1477  products have been read successfully by 2017-05-23 23:41:24.217662
# LabeledPairs And Products for nike_air_max have been read successfully by 2017-05-23 23:41:24.221362
# train instances is being generated by 2017-05-23 23:41:24.223962
# 14286 train instances have been generated by 2017-05-23 23:41:25.926657
# all_day_nike_air_max_TrainData_Updated_OneHot2 has been saved successfully by 2017-05-23 23:41:27.469468
# hdfs://osldevptst01.host.gittigidiyor.net:8020/user/root/data/Day1_camasir_makinesi_Data/all_day_camasir_makinesi_journey_products 1858  products have been read successfully by 2017-05-23 23:41:28.711999
# LabeledPairs And Products for camasir_makinesi have been read successfully by 2017-05-23 23:41:28.715429
# train instances is being generated by 2017-05-23 23:41:28.718122
# 10814 train instances have been generated by 2017-05-23 23:41:30.456214
# all_day_camasir_makinesi_TrainData_Updated_OneHot2 has been saved successfully by 2017-05-23 23:41:31.694024
# hdfs://osldevptst01.host.gittigidiyor.net:8020/user/root/data/Day1_bosch_Data/all_day_bosch_journey_products 1739  products have been read successfully by 2017-05-23 23:41:32.946068
# LabeledPairs And Products for bosch have been read successfully by 2017-05-23 23:41:32.949581
# train instances is being generated by 2017-05-23 23:41:32.952006
# 462 train instances have been generated by 2017-05-23 23:41:34.446218
# all_day_bosch_TrainData_Updated_OneHot2 has been saved successfully by 2017-05-23 23:41:35.177985
# hdfs://osldevptst01.host.gittigidiyor.net:8020/user/root/data/Day1_jant_Data/all_day_jant_journey_products 1301  products have been read successfully by 2017-05-23 23:41:36.450357
# LabeledPairs And Products for jant have been read successfully by 2017-05-23 23:41:36.455726
# train instances is being generated by 2017-05-23 23:41:36.458092
# 1930 train instances have been generated by 2017-05-23 23:41:37.851187
# all_day_jant_TrainData_Updated_OneHot2 has been saved successfully by 2017-05-23 23:41:38.560043
# hdfs://osldevptst01.host.gittigidiyor.net:8020/user/root/data/Day1_kot_ceket_Data/all_day_kot_ceket_journey_products 271  products have been read successfully by 2017-05-23 23:41:39.727599
# LabeledPairs And Products for kot_ceket have been read successfully by 2017-05-23 23:41:39.730626
# train instances is being generated by 2017-05-23 23:41:39.733061
# 864 train instances have been generated by 2017-05-23 23:41:40.989980
# all_day_kot_ceket_TrainData_Updated_OneHot2 has been saved successfully by 2017-05-23 23:41:41.532201
# 2017-05-23 23:41:41.536394: DONE
# ########################################################################################
# ########################################################################################
# ########################################################################################
